# %% [markdown]
# # Machine Learning on Cell: KMeans

# %%
from sklearn.cluster import KMeans

import pandas as pd

import pandas.io.sql as sqlio

import psycopg2

import matplotlib.pyplot as plt

# %%
n_clusters = 5
zoom = 5

# %%
conn = psycopg2.connect("dbname=cell user=cell_master password=38fn3k39erj34n8 host=kepler port=5632")
sql = "select * from ml.pop_structure_%s" % zoom

# %%
data = sqlio.read_sql_query(sql, conn)
data.columns = ["z", "x", "y", "p18", "p1864", "p64"]
data.head()
# Out:
#    z    x    y   p18  p1864   p64
# 0  5  156  491  0.18   0.68  0.14
# 1  5  156  492  0.15   0.68  0.17
# 2  5  156  493  0.16   0.69  0.15
# 3  5  156  494  0.11   0.67  0.21
# 4  5  156  495  0.16   0.66  0.18

# %%
data.describe()
# Out:
#              z             x             y           p18         p1864  \
# count  10679.0  10679.000000  10679.000000  10679.000000  10679.000000
# mean       5.0    640.057028    377.981927      0.149886      0.691578
# std        0.0    240.863799    115.691293      0.077750      0.116142
# min        5.0    156.000000    164.000000      0.000000      0.000000
# 25%        5.0    421.000000    274.000000      0.110000      0.640000
# 50%        5.0    633.000000    355.000000      0.150000      0.680000
# 75%        5.0    819.000000    479.000000      0.190000      0.730000
# max        5.0   1169.000000    707.000000      0.570000      1.000000
#
#                 p64
# count  10679.000000
# mean       0.158697
# std        0.119730
# min        0.000000
# 25%        0.080000
# 50%        0.150000
# 75%        0.210000
# max        1.000000

# %%
kmeans = KMeans(n_clusters=n_clusters).fit(data[["p18", "p1864", "p64"]])
kmeans.predict(data[["p18", "p1864", "p64"]])
# Out:
# array([4, 4, 4, ..., 4, 3, 4], dtype=int32)

# %%
data["cluster"] = kmeans.predict(data[["p18", "p1864", "p64"]])
data[["cluster", "p18", "p1864", "p64", "cluster"]].head()
# Out:
#    cluster   p18  p1864   p64  cluster
# 0        4  0.18   0.68  0.14        4
# 1        4  0.15   0.68  0.17        4
# 2        4  0.16   0.69  0.15        4
# 3        1  0.11   0.67  0.21        1
# 4        4  0.16   0.66  0.18        4

# %%
data[[ "cluster", "p18", "p1864", "p64" ]].groupby(["cluster"]).agg([ "count", "mean" ])
# Out:
#           p18           p1864             p64
#         count      mean count      mean count      mean
# cluster
# 0         891  0.025039   891  0.961392   891  0.013771
# 1        2980  0.122852  2980  0.617201  2980  0.260205
# 2        2078  0.253128  2078  0.687007  2078  0.060067
# 3         232  0.018793   232  0.337543   232  0.643922
# 4        4498  0.151592  4498  0.707779  4498  0.140694

# %%
fig1, ax1 = plt.subplots()
ax1.set_title("kk")
ax1.boxplot(data[data.cluster == 1][["p18", "p1864", "p64" ]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f7ac010b2e0>,
#   <matplotlib.lines.Line2D at 0x7f7ac010b670>,
#   <matplotlib.lines.Line2D at 0x7f7ac0119bb0>,
#   <matplotlib.lines.Line2D at 0x7f7ac0119f40>,
#   <matplotlib.lines.Line2D at 0x7f7ac0137520>,
#   <matplotlib.lines.Line2D at 0x7f7ac01378b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7ac010ba00>,
#   <matplotlib.lines.Line2D at 0x7f7ac010bd00>,
#   <matplotlib.lines.Line2D at 0x7f7ac0129310>,
#   <matplotlib.lines.Line2D at 0x7f7ac01296a0>,
#   <matplotlib.lines.Line2D at 0x7f7ac0137c40>,
#   <matplotlib.lines.Line2D at 0x7f7ac0137fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f7ac00f9f10>,
#   <matplotlib.lines.Line2D at 0x7f7ac0119820>,
#   <matplotlib.lines.Line2D at 0x7f7ac0137190>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7ac01190d0>,
#   <matplotlib.lines.Line2D at 0x7f7ac0129a30>,
#   <matplotlib.lines.Line2D at 0x7f7ac00c23a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7ac0119490>,
#   <matplotlib.lines.Line2D at 0x7f7ac0129dc0>,
#   <matplotlib.lines.Line2D at 0x7f7ac00c2730>],
#  'means': []}

# %%
cur = conn.cursor()
sql = ""

for i, r in data.iterrows():
    sql = sql + 'update cell_data.data set data = data || \'{ "8932": %i }\'::jsonb where zoom=%i and x=%i and y=%i;' % (r["cluster"], r["z"], r["x"], r["y"])

# %%
cur.execute(sql)
conn.commit()
cur.close()
conn.close()
